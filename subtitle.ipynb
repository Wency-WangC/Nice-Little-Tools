# %%
import whisper
from docx import Document

audio_file = r"C:\Users\PC\Downloads\College St 4.m4a"
word_file_path = r"C:\Users\PC\Downloads\College St 4.docx"

# 加载 Whisper 模型
model = whisper.load_model("turbo")

# 转录音频或视频文件
result = model.transcribe(audio_file, verbose=False)

# 获取转录的文本
transcription_text = result["text"]

doc = Document()
doc.add_paragraph(transcription_text)

# 添加标题
doc.add_heading('Transcription Result', 0)

# 添加转录文本
doc.add_paragraph(transcription_text)

# 保存文档
doc.save(word_file_path)

print(f"转录文本已保存为：{word_file_path}")
# Out:
# C:\Users\PC\whisper-env\lib\site-packages\whisper\__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# ...

# %%
下面的是有ui界面的

# %%
try:
    import whisper
except ModuleNotFoundError:
    raise ModuleNotFoundError("Whisper module is not installed. Please install it using 'pip install openai-whisper'.")

try:
    import easygui
except ModuleNotFoundError:
    raise ModuleNotFoundError("EasyGUI module is not installed. Please install it using 'pip install easygui'.")

import os
import tkinter as tk
from tkinter import simpledialog, messagebox
from docx import Document
from tqdm import tqdm

def transcribe_audio(file_path, output_path):
    """使用Whisper转录音频，并保存到Word文档"""
    model = whisper.load_model("turbo")
    print("当前处理文件路径:", file_path)
    result = model.transcribe(file_path, verbose=False)
    transcription_text = result["text"]
    
    doc = Document()
    doc.add_heading('Transcription Result', 0)
    doc.add_paragraph(transcription_text)
    doc.save(output_path)

def main():
    root = tk.Tk()
    root.withdraw()  # 隐藏主窗口
    
    # 选择音频文件所在的目录
    folder_path = easygui.diropenbox(title="请选择包含音频文件的文件夹")
    if not folder_path:
        messagebox.showinfo("提示", "未选择文件夹，程序退出。")
        return
    
    # 获取音频文件
    audio_extensions = (".mp4", ".mp3", ".wav", ".m4a")
    audio_files = [f for f in os.listdir(folder_path) if f.endswith(audio_extensions)]
    
    if not audio_files:
        messagebox.showinfo("提示", "未找到音频文件，程序退出。")
        return
    
    # 让用户选择要转录的音频
    selected_files = easygui.multchoicebox("请选择要转录的音频文件", "音频选择", audio_files)
    if not selected_files:
        messagebox.showinfo("提示", "未选择音频文件，程序退出。")
        return
    
    # 处理选中的音频
    for file in tqdm(selected_files, desc="转录进度", unit="file", leave=True, ncols=100):
        file_path = os.path.join(folder_path, file)
        default_output_path = os.path.join(folder_path, f"{os.path.splitext(file)[0]}.docx")
        
        # 询问是否修改文件名
        new_name = simpledialog.askstring("文件名", f"输入{file}的保存文件名(不输入则使用默认名):")
        output_path = default_output_path if not new_name else os.path.join(folder_path, f"{new_name}.docx")
        
        transcribe_audio(file_path, output_path)
    
    messagebox.showinfo("完成", "所有选定文件已成功转录！")

if __name__ == "__main__":
    main()
# Out:
# 转录进度:   0%|                                                             | 0/5 [00:00<?, ?file/s]C:\Users\PC\whisper-env\lib\site-packages\whisper\__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues re
# ...

# %%
# !pip install easygui

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python313\python.exe

# %%
# !pip install -U openai-whisper
# Out:
# ...
#      -------------------------------------- 803.2/803.2 kB 8.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ------------------------------------- 879.4/879.4 kB 11.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 109.3/109.3 MB 10.2 MB/s eta 0:00:00
# ...
#      --------------------------------------- 12.9/12.9 MB 11.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 69.7/69.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 8.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 38.1/38.1 MB 9.9 MB/s eta 0:00:00
# ...
